# %%
import pandas as pd
import os

# %%
data = pd.read_csv('shopify.csv')
data
# Out:
#       Rank                                               Name      Country  \
# 0      931  All Things Fermented | Home Brew Shop NZ | Sup...  New Zealand
# 1      932                                      Piano Traders  New Zealand
# 2      933                                  Seriously Healthy  New Zealand
# 3      934                                         Kiwigarden  New Zealand
# 4      935  Andrew Cadenhead - Accident Compensation Law S...  New Zealand
# ...    ...                                                ...          ...
# 4373   476                                     Petite Eats NZ  New Zealand
# 4374   477                                       Avoca Beauty  New Zealand
# 4375   478                             SoL Cups - New Zealand  New Zealand
# 4376   479                                    MatchaMatcha NZ  New Zealand
# 4377   480                                          Beer Jerk  New Zealand
#
#                               Website  \
# ...

# %%
data2 = data.sort_values(by = 'Rank', ascending = True )
data2.head(65)
# Out:
#       Rank                  Name      Country  \
# 4228     1      Culture Kings NZ  New Zealand
# 4258     1      Culture Kings NZ  New Zealand
# 4229     2          Empire Skate  New Zealand
# 4259     2          Empire Skate  New Zealand
# 4230     3          Jamie Kay NZ  New Zealand
# ...    ...                   ...          ...
# 2938    31            TSB Living  New Zealand
# 2939    32     Supplements.co.nz  New Zealand
# 2940    33                Kowtow  New Zealand
# 2941    34          Wine Central  New Zealand
# 2942    35  Allbirds New Zealand  New Zealand
#
#                               Website  \
# 4228  https://www.culturekings.co.nz/
# 4258  https://www.culturekings.co.nz/
# 4229   https://www.empireskate.co.nz/
# 4259   https://www.empireskate.co.nz/
# 4230          https://jamiekay.co.nz/
# ...                               ...
# 2938     https://www.tsbliving.co.nz/
# 2939   https://www.supplements.co.nz/
# 2940   https://nz.kowtowclothing.com/
# ...

# %%
print(data.isnull().sum())
# Out:
# Rank            0
# Name           65
# Country         0
# Website         0
# Facebook      891
# Twitter      3674
# Instagram    1323
# Pinterest    3865
# Snapchat     4362
# Youtube      3771
# Alexa           0
# Growing         0
# dtype: int64

# %%
data2.drop_duplicates(subset = 'Rank', keep = 'first', inplace = True)

# %%
data2.to_csv('Shopify_data.csv')

# %%
new_data = pd.read_csv('Shopify_data.csv')
new_data
# Out:
#       Unnamed: 0  Rank                       Name      Country  \
# 0           4228     1           Culture Kings NZ  New Zealand
# 1           4229     2               Empire Skate  New Zealand
# 2           4230     3               Jamie Kay NZ  New Zealand
# 3           4231     4              Vapoureyes NZ  New Zealand
# 4           4232     5              The Good Room  New Zealand
# ...          ...   ...                        ...          ...
# 4343         293  4794           YuDon Wellington  New Zealand
# 4344         294  4795      Zing Toys New Zealand  New Zealand
# 4345         295  4796                    ZoopaNZ  New Zealand
# 4346         296  4797  ZRC Superior Zinc Coating  New Zealand
# 4347         297  4798                       ZUBU  New Zealand
#
#                               Website  \
# 0     https://www.culturekings.co.nz/
# 1      https://www.empireskate.co.nz/
# 2             https://jamiekay.co.nz/
# 3       https://www.vapoureyes.co.nz/
# ...
